# %%
import dlt
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
#     <html>
#       <div style="font-size:18px">
#         The Delta Live Tables (DLT) module is not supported on this cluster.
#         You should either <a href="?o=4201568283894456#joblist/pipelines/create?initialSource=%2FUsers%2Fpatel.riyas%40northeastern.edu%2FMedallian_DLT&redirectNotebookId=3149668304415064">create a new pipeline</a> or use an existing pipeline to run DLT code.
#       </div>
#     </html>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File <command-4603608570539197>, line 1
# ----> 1 import dlt
#       2 from pyspark.sql.functions import *
#       3 from pyspark.sql.types import *
#
# ModuleNotFoundError: No module named 'dlt'

# %%
import dlt
from pyspark.sql.functions import *

@dlt.table
def bronze_employee():
    df = spark.read.table("workspace.damg7370.sample_employee_dataset_demo")
    return df

# %%
@dlt.view
def silver_employee():
    df = spark.read.table("LIVE.bronze_employee")

    # Data type conversions
    df = df.withColumn("Performance_Score", col("Performance_Score").cast("int"))
    df = df.withColumn("Monthly_Salary", col("Monthly_Salary").cast("double"))

    # Trim whitespace in text fields
    df = df.withColumn("Name", trim(col("Name")))
    df = df.withColumn("Department", trim(col("Department")))

    # Add a new column to track record status
    df = df.withColumn("row_status", lit("New"))

    return df

# %%
@dlt.table
def gold_employee_demo():
    df = spark.read.table("LIVE.silver_employee")
    # df = df.groupBy("id").agg(max("row_status").alias("row_status"))
    return df
