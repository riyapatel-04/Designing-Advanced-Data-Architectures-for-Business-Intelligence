# %%
# %sql
select * from workspace.damg7370.sample_employee_dataset;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
create table workspace.damg7370.sample_employee_dataset_demo as 
select * from workspace.damg7370.sample_employee_dataset
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4603608570539201>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'create table workspace.damg7370.sample_employee_dataset_demo as \nselect * from workspace.damg7370.sample_employee_dataset\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %sql
select * from workspace.damg7370.sample_employee_dataset_demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DELETE FROM workspace.damg7370.sample_employee_dataset_demo
WHERE Employee_ID = 'E106'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from workspace.damg7370.sample_employee_dataset_demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_ID</th><th>Name</th><th>Department</th><th>Performance_Score</th><th>Monthly_Salary</th></tr></thead><tbody><tr><td>E101</td><td>Alice Johnson</td><td>Marketing</td><td>88</td><td>5400</td></tr><tr><td>E102</td><td>Bob Smith</td><td>Finance</td><td>92</td><td>6000</td></tr><tr><td>E103</td><td>Charlie Patel</td><td>Engineering</td><td>76</td><td>6800</td></tr><tr><td>E104</td><td>Diana Chen</td><td>Human Resources</td><td>85</td><td>5200</td></tr><tr><td>E105</td><td>Eric Lopez</td><td>Engineering</td><td>90</td><td>7100</td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO workspace.damg7370.sample_employee_dataset_demo
(Employee_ID, Name, Department, Performance_Score, Monthly_Salary)
VALUES ('E106', 'Fiona Davis', 'Marketing', 79, 5000);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from workspace.damg7370.sample_employee_dataset_demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
